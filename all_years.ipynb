# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import os 
from numpy import random

# %%
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in 'C:\\Users\\bulsa\\Final_project': ['.ipynb_checkpoints', '2009.csv', '2010.csv', '2011.csv', '2012.csv', '2013.csv', '2014.csv', '2015.csv', '2016.csv', '2017.csv', '2018.csv', '2022.csv', 'airlines.csv', 'airports.csv', 'all_years.ipynb', 'flights.csv', 'new.ipynb', 'new2.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb']

# %%
csv_path_files_list = []
for i in range(2009,2018):
    csv_path_files_list.append('Final_project/'+ str(i) +'.csv')

csv_list = []

for file in sorted(csv_path_files_list):
    csv_list.append(pd.read_csv(file).assign(File_Name = os.path.basename(file)))

csv_list_delay = []
for csv_list_year in csv_list:
    csv_list_delay.append(csv_list_year[(csv_list_year['ARR_DELAY'] > 0)])
del csv_list

# %%
cd
# Out:
# C:\Users\bulsa

# %%
a_with_delay_dest = pd.concat(csv_list_delay, ignore_index=True)

# %%
# Delay analysis for period 2014-2018
a_average_flight_delay_dest = a_with_delay_dest['ARR_DELAY'].mean()
a_median_flight_delay_dest = a_with_delay_dest['ARR_DELAY'].median()
a_skewness_flight_delay_dest = a_with_delay_dest['ARR_DELAY'].skew()
a_kurtosis_flight_delay_dest = a_with_delay_dest['ARR_DELAY'].kurtosis()

print(
    f"Datas of Arrival delay flights - Mean value: {a_average_flight_delay_dest} "
    f"Median value: {a_median_flight_delay_dest} Skewness: {a_skewness_flight_delay_dest} "
    f"Kurtosis: {a_kurtosis_flight_delay_dest}")

a_with_delay_dest.hist(column='ARR_DELAY', bins=100)
plt.title('ARRIVAL delays 2014-2018', fontsize=16)
plt.ylabel('Flight', fontsize=14)
plt.xlabel('Minutes', fontsize=14)
plt.show()
# Out:
# Datas of Arrival delay flights - Mean value: 31.866393808878637 Median value: 15.0 Skewness: 5.951926940963529 Kurtosis: 77.63228952101052

# %%
# Delay per month (2014-2018), mean and median value

for i in range(len(csv_list_delay)):
    csv_list_delay[i]['FL_DATE_month'] = pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.month
    
    plt.figure(figsize=(25, 12)).subplots_adjust(hspace = 0.5)

    plt.subplot(2, 2 ,1)
    csv_list_delay[i].groupby('FL_DATE_month').ARR_DELAY.mean().plot.bar()
    plt.title('Mean ARRIVAL delays by month for ' + year[i], fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('month of the year', fontsize=14)

    plt.subplot(2, 2 ,2)
    csv_list_delay[i].groupby('FL_DATE_month').ARR_DELAY.median().plot.bar()
    plt.title('Median ARRIVAL delays by month for ' + year[i], fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('month of the year', fontsize=14)

    plt.show()
# Out:
# C:\Users\bulsa\AppData\Local\Temp\ipykernel_30740\4222045233.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_list_delay[i]['FL_DATE_month'] = pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.month

# %%
year = ['2009','2010','2011','2012','2013','2014', '2015', '2016', '2017', '2018','2022']

# %%
# Delay per month (2014-2018), mean and median value

for i in range(len(csv_list_delay)):
    csv_list_delay[i]['FL_DATE_month'] = pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.month
    
    plt.figure(figsize=(25, 12)).subplots_adjust(hspace = 0.5)

    plt.subplot(2, 2 ,1)
    csv_list_delay[i].groupby('FL_DATE_month').ARR_DELAY.mean().plot.bar()
    plt.title('Mean ARRIVAL delays by month for ' + year[i], fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('month of the year', fontsize=14)

    plt.subplot(2, 2 ,2)
    csv_list_delay[i].groupby('FL_DATE_month').ARR_DELAY.median().plot.bar()
    plt.title('Median ARRIVAL delays by month for ' + year[i], fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('month of the year', fontsize=14)
    
    plt
    
    

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11544\4222045233.py in <module>
#       8     plt.subplot(2, 2 ,1)
#       9     csv_list_delay[i].groupby('FL_DATE_month').ARR_DELAY.mean().plot.bar()
# ---> 10     plt.title('Mean ARRIVAL delays by month for ' + year[i], fontsize=16)
#      11     plt.ylabel('Minutes', fontsize=14)
#      12     plt.xlabel('month of the year', fontsize=14)
#
# IndexError: list index out of range

# %%
# Delay per month (2014-2018), mean and median value
import json
for i in range(len(csv_list_delay)):
    csv_list_delay[i]['FL_DATE_year']= pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.year
    
    plt.figure(figsize=(25, 12)).subplots_adjust(hspace = 0.5)

    plt.plot(2, 2,1 )
    csv_list_delay[i].groupby('FL_DATE_year').ARR_DELAY.mean().plot.bar()
    plt.title('Mean ARRIVAL delays by year for year ' , fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('year', fontsize=14)
    
    # Store the data in a dictionary
    data_to_store = {'year': year,'Minutes':Minutes}

    # Save the data to a JSON file
    with open('flight_delay_data.json', 'w') as json_file:
        
        json.dump(data_to_store, json_file)
    
  
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30740\2575272124.py in <module>
#      13
#      14     # Store the data in a dictionary
# ---> 15     data_to_store = {'year': year,'Minutes':Minutes}
#      16
#      17     # Save the data to a JSON file
#
# NameError: name 'Minutes' is not defined

# %%
year
# Out:
# ['2014', '2015', '2016', '2017', '2018']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming csv_list_delay is a list of DataFrames, and year is a list of years

# Create an empty list to accumulate data
all_data = []

for i in range(len(csv_list_delay)):
    csv_list_delay[i]['FL_DATE_month'] = pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.month

    plt.figure(figsize=(12, 6))

    # Plot mean arrival delays
    plt.subplot(1, 2, 1)
    mean_delays = csv_list_delay[i].groupby('FL_DATE_month').ARR_DELAY.mean()
    plt.plot(mean_delays.index, mean_delays.values, label=year[i])
    plt.title('Mean ARRIVAL delays by month', fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('Month of the year', fontsize=14)
    plt.legend()

    # Plot median arrival delays
    plt.subplot(1, 2, 2)
    median_delays = csv_list_delay[i].groupby('FL_DATE_month').ARR_DELAY.median()
    plt.plot(median_delays.index, median_delays.values, label=year[i])
    plt.title('Median ARRIVAL delays by month', fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('Month of the year', fontsize=14)
    plt.legend()

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11544\2210958833.py in <module>
#      15     plt.subplot(1, 2, 1)
#      16     mean_delays = csv_list_delay[i].groupby('FL_DATE_month').ARR_DELAY.mean()
# ---> 17     plt.plot(mean_delays.index, mean_delays.values, label=year[i])
#      18     plt.title('Mean ARRIVAL delays by month', fontsize=16)
#      19     plt.ylabel('Minutes', fontsize=14)
#
# IndexError: list index out of range

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Create an empty list to accumulate data
all_mean_delays = []

# Extract unique years
unique_years = set()

# Extract mean delays by year
for i in range(len(csv_list_delay)):
    csv_list_delay[i]['FL_DATE_year'] = pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.year
    unique_years.update(csv_list_delay[i]['FL_DATE_year'])
    mean_delays = csv_list_delay[i].groupby('FL_DATE_year').ARR_DELAY.mean()
    all_mean_delays.append(mean_delays)

    
# Combine data and plot a bar graph
combined_mean_delays = pd.concat(all_mean_delays, axis=1)
combined_mean_delays.columns = sorted(unique_years)  # Sort the columns



combined_mean_delays.plot(kind='bar', figsize=(12, 6), width=4.5)
plt.title('Mean ARRIVAL delays by year', fontsize=16)
plt.ylabel('Minutes', fontsize=14)
plt.xlabel('Year', fontsize=12)

tick_positions = range(len(combined_mean_delays))
plt.xticks(tick_positions, combined_mean_delays.index, rotation=0)

plt.legend(title='Year')
plt.show()
# Out:
# C:\Users\bulsa\AppData\Local\Temp\ipykernel_30740\1720379802.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_list_delay[i]['FL_DATE_year'] = pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming csv_list_delay is a list of DataFrames

# Create an empty list to accumulate data
all_mean_delays = []

# Extract unique years
unique_years = set()

# Extract mean delays by year
for i in range(len(csv_list_delay)):
    csv_list_delay[i]['FL_DATE_year'] = pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.year
    unique_years.update(csv_list_delay[i]['FL_DATE_year'])
    mean_delays = csv_list_delay[i].groupby('FL_DATE_year').ARR_DELAY.mean()
    all_mean_delays.append(mean_delays)

# Combine data and plot a bar graph
combined_mean_delays = pd.concat(all_mean_delays, axis=1)
combined_mean_delays.columns = sorted(unique_years)  # Sort the columns

# Ensure all years are included in the plot
for year in unique_years:
    if year not in combined_mean_delays.index:
        combined_mean_delays.loc[year] = None

combined_mean_delays.sort_index(inplace=True)  # Sort the index

combined_mean_delays.plot(kind='bar', figsize=(18, 6))
plt.title('Mean ARRIVAL delays by year', fontsize=16)
plt.ylabel('Minutes', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.legend(title='Year')
plt.show()
# Out:
# C:\Users\bulsa\AppData\Local\Temp\ipykernel_11544\3914795926.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_list_delay[i]['FL_DATE_year'] = pd.to_datetime(csv_list_delay[i]['FL_DATE']).dt.year
