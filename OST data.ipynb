# %%
import pandas as pd

# %%
pd.read_csv('Final_project/2022.csv')
# Out:
#                       FL_DATE MKT_UNIQUE_CARRIER  MKT_CARRIER_FL_NUM DEST  \
# 0        1/1/2022 12:00:00 AM                 AA                   1  LAX
# 1        1/1/2022 12:00:00 AM                 AA                  10  JFK
# 2        1/1/2022 12:00:00 AM                 AA                1003  ORD
# 3        1/1/2022 12:00:00 AM                 AA                1004  FLL
# 4        1/1/2022 12:00:00 AM                 AA                1007  STL
# ...                       ...                ...                 ...  ...
# 563732  1/31/2022 12:00:00 AM                 WN                 996  LAS
# 563733  1/31/2022 12:00:00 AM                 WN                 996  MDW
# 563734  1/31/2022 12:00:00 AM                 WN                 997  SNA
# 563735  1/31/2022 12:00:00 AM                 WN                 998  OAK
# 563736  1/31/2022 12:00:00 AM                 WN                 999  ONT
#
#         CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF
# ...

# %%
cd
# Out:
# C:\Users\bulsa

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt # plotting
import os # accessing directory structure
#import seaborn as sns
#from fitter import Fitter, get_common_distributions, get_distributions
import seaborn as sns
from numpy import random

# %%
for i in range(len(csv_list_delay)):
    plt.figure(figsize=(25, 12)).subplots_adjust(hspace = 1)

    plt.subplot(2, 2 ,1)
    mean_origin = csv_list_delay[i].groupby('DEST').ARR_DELAY.mean().sort_values(ascending=False)
    mean_origin[:20].plot.bar()
    plt.title('Mean ARRIVAL delays by Destination for ' + year[i], fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('City', fontsize=14)

    plt.subplot(2, 2 ,2)
    median_origin = csv_list_delay[i].groupby('DEST').ARR_DELAY.median().sort_values(ascending=False)
    median_origin[:20].plot.bar()
    plt.title('Median ARRIVAL delays by Destination for ' + year[i], fontsize=16)
    plt.ylabel('Minutes', fontsize=14)
    plt.xlabel('City', fontsize=14)

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19756\3446513587.py in <module>
# ----> 1 for i in range(len(csv_list_delay)):
#       2     plt.figure(figsize=(25, 12)).subplots_adjust(hspace = 1)
#       3
#       4     plt.subplot(2, 2 ,1)
#       5     mean_origin = csv_list_delay[i].groupby('DEST').ARR_DELAY.mean().sort_values(ascending=False)
#
# NameError: name 'csv_list_delay' is not defined

# %%
import pandas as pd

# Assuming you have the Kaggle flight data CSV file
kaggle_data_path = 'Final_project/2022.csv'

# Load the data into a Pandas DataFrame
flight_data = pd.read_csv(kaggle_data_path)

# Convert the 'FL_DATE' column to datetime
flight_data['FL_DATE'] = pd.to_datetime(flight_data['FL_DATE'])

# Filter data for the year 2018
flight_data_2018 = flight_data[flight_data['FL_DATE'].dt.year == 2022]

# Group by destination and calculate the average delay
average_delay_by_destination = flight_data_2018.groupby('DEST')['DEP_DELAY'].mean().reset_index()

# Display the result
print(average_delay_by_destination)
# Out:
#     DEST  DEP_DELAY
# 0    ABE   6.653646
# 1    ABI   0.979730
# 2    ABQ  11.361239
# 3    ABR  31.466667
# 4    ABY   4.125000
# ..   ...        ...
# 364  XNA   6.719000
# 365  XWA  11.232323
# 366  YAK  18.462963
# 367  YKM   7.690909
# 368  YUM   9.656250
#
# [369 rows x 2 columns]

# %%
cd
# Out:
# C:\Users\bulsa

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the Kaggle flight data CSV file
kaggle_data_path = 'Final_project/2022.csv'

# Load the data into a Pandas DataFrame
flight_data = pd.read_csv(kaggle_data_path)

# Convert the 'FL_DATE' column to datetime
flight_data['FL_DATE'] = pd.to_datetime(flight_data['FL_DATE'])

# Filter data for the year 2022
flight_data_2022 = flight_data[flight_data['FL_DATE'].dt.year == 2022]

# Group by destination and calculate the average departure delay
average_delay_by_destination = flight_data_2022.groupby('DEST')['DEP_DELAY'].mean().reset_index()

# Display the result
print(average_delay_by_destination)

# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(average_delay_by_destination['DEST'], average_delay_by_destination['DEP_DELAY'], color='skyblue')
plt.xlabel('Destination')
plt.ylabel('Average Departure Delay (minutes)')
plt.title('Average Departure Delay by Destination for Year 2022')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.tight_layout()
plt.show()
# Out:
#     DEST  DEP_DELAY
# 0    ABE   6.653646
# 1    ABI   0.979730
# 2    ABQ  11.361239
# 3    ABR  31.466667
# 4    ABY   4.125000
# ..   ...        ...
# 364  XNA   6.719000
# 365  XWA  11.232323
# 366  YAK  18.462963
# 367  YKM   7.690909
# 368  YUM   9.656250
#
# [369 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the Kaggle flight data CSV file
kaggle_data_path = 'Final_project/2022.csv'

# Load the data into a Pandas DataFrame
flight_data = pd.read_csv(kaggle_data_path)

# Convert the 'FL_DATE' column to datetime
flight_data['FL_DATE'] = pd.to_datetime(flight_data['FL_DATE'])

# Filter data for the year 2022
flight_data_2022 = flight_data[flight_data['FL_DATE'].dt.year == 2022]

# Group by destination and calculate the average departure delay
average_delay_by_destination = flight_data_2022.groupby('DEST')['DEP_DELAY'].mean().reset_index()

# Select the top 10 destinations based on average departure delay
top_10_destinations = average_delay_by_destination.nlargest(10, 'DEP_DELAY')

# Display the result
print(top_10_destinations)

# Create a bar graph for the top 10 destinations
plt.figure(figsize=(12, 6))
plt.bar(top_10_destinations['DEST'], top_10_destinations['DEP_DELAY'], color='skyblue')
plt.xlabel('Destination')
plt.ylabel('Average Departure Delay (minutes)')
plt.title('Top 10 Destinations by Average Departure Delay for Year 2022')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.tight_layout()
plt.show()
# Out:
#     DEST  DEP_DELAY
# 24   ATY  58.000000
# 274  PPG  57.000000
# 275  PQI  55.061224
# 155  HIB  54.159091
# 20   ART  44.948718
# 233  MQT  42.603960
# 50   BRD  40.617021
# 105  DVL  35.469388
# 40   BJI  34.864407
# 292  RHI  34.566667
